# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Observable Trends
###Of the 1163 active players, the vast majority are male (81%). There also exists, a smaller, but notable proportion of female players (18%).
#Our peak age demographic falls between 20-24 (44.79%) with secondary groups falling between 15-19 (18.58%) and 25-29 (13.37%).
#The age group that spends the most money is the 20-24 with 1,114.06 dollars as total purchase value and an average purchase of 4.32. In contrast, the demographic group that has the highest average purchase is the 35-39 with 4.76 and a total purchase value of 147.67###.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# Raw data file
file_to_load = "Resources/purchase_data.json"

# Read purchasing file and store into pandas data frame
purchase_data = pd.read_json(file_to_load)
purchase_data.head()
# Out:
#    Age Gender  Item ID                                  Item Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN
# 0     Aelalis34
# 1        Eolo46
# 2   Assastnya25
# 3  Pheusrical25
# 4        Aela59

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
#Number of Players
player_demographics = purchase_data.loc[:, ["Gender", "SN", "Age"]]
player_demographics = player_demographics.drop_duplicates()
num_players = player_demographics.count()[0]
#display the total number of players
pd.DataFrame({"Total Players" : [num_players]})
# Out:
#    Total Players
# 0            573

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Calculations for unique items, average price, purchase count, and revenue
number_of_unique_items = len((purchase_data["Item ID"]).unique())
average_price = (purchase_data["Price"]).mean()
number_of_purchases = (purchase_data["Item ID"]).count()
total_revenue = (purchase_data["Price"]).sum()

# Create data frame with obtained values
summary_df = pd.DataFrame({"Number of Unique Items":[number_of_unique_items],
                           "Average Price":[average_price], 
                           "Number of Purchases": [number_of_purchases], 
                           "Total Revenue": [total_revenue]})

# Format with currency style
summary_df.style.format({'Average Price':"${:,.2f}",
                         'Total Revenue': '${:,.2f}'})
# Out:
# <style  type="text/css" >
# </style><table id="T_1ffb1fb0_a8fb_11e9_b965_28c2dd9f6d72" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ffb1fb0_a8fb_11e9_b965_28c2dd9f6d72level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1ffb1fb0_a8fb_11e9_b965_28c2dd9f6d72row0_col0" class="data row0 col0" >183</td>
#                         <td id="T_1ffb1fb0_a8fb_11e9_b965_28c2dd9f6d72row0_col1" class="data row0 col1" >$2.93</td>
#                         <td id="T_1ffb1fb0_a8fb_11e9_b965_28c2dd9f6d72row0_col2" class="data row0 col2" >780</td>
#                         <td id="T_1ffb1fb0_a8fb_11e9_b965_28c2dd9f6d72row0_col3" class="data row0 col3" >$2,286.33</td>
#             </tr>
#     </tbody></table>

# %%
purchase_data["Price"].head()
average = purchase_data["Price"].mean()
average
# Out:
# 2.931192307692303

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
# The value_counts method counts unique values in a column
#count = purchase_data["Gender"].value_counts()
count = player_demographics["Gender"].value_counts()
percent = count/num_players *100
gender_demographics = pd.DataFrame({"Total Count":count, "Percentage of Players per gender": percent})
gender_demographics
# Out:
#                        Total Count  Percentage of Players per gender
# Male                           465                         81.151832
# Female                         100                         17.452007
# Other / Non-Disclosed            8                          1.396161

# %%
# Using GroupBy in order to separate the data into fields according to "Gender" values
#grouped_by_gender_df = purchase_data.groupby(['Gender'])
grouped_by_gender_df = player_demographics.groupby(['Gender'])
grouped_by_gender_df.count()
# Out:
#                         SN  Age
# Gender
# Female                 100  100
# Male                   465  465
# Other / Non-Disclosed    8    8

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
player_demographics = purchase_data.loc[:, ["Gender", "SN", "Age"]]
num_players = player_demographics.count()[0]
#display the total number of players
pd.DataFrame({"Total Purchase" : [num_players]})
# Out:
#    Total Purchase
# 0             780

# %%
purchase_data["Price"].head()
average_purchase_price = purchase_data["Price"].mean()
average
# Out:
# 2.931192307692303

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Create the bins in which Data will be held
# Bins are 0-15, 16-30, 31-45, 46-60, 61-75, 76-90.   
#bins = [0, 15, 30, 45, 60, 75, 90]

# %%
# Create the names for the four bins
#group_names =["Infant", "Youth", "Adult", "Senior", "Senior2"]

# %%
#df = "Resources/purchase_data.json" 
df = pd.read_json(file_to_load)
purchase_data.head()
# Out:
#    Age Gender  Item ID                                  Item Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN
# 0     Aelalis34
# 1        Eolo46
# 2   Assastnya25
# 3  Pheusrical25
# 4        Aela59

# %%
# Create the bins in which Data will be held
# Bins are 0-15, 16-30, 31-45, 46-60, 61-75, 76-90.   
bins = [0, 15, 30, 45, 60, 75, 90]

# Create the names for the four bins
group_names =["Infant", "Youth", "Adult", "Senior", "Senior1", "Senior2"]

# %%
df["Age Category"] = pd.cut(df["Age"], bins, labels=group_names)
df
# Out:
#      Age                 Gender  Item ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 21    15                   Male        3
# 22    11                 Female       11
# 23    19                   Male      183
# 24    11                   Male       65
# 25    21                   Male       63
# 26    29                   Male      132
# 27    34                   Male      106
# 28    15                   Male       49
# 29    16                 Female       45
# ..   ...                    ...      ...
# 750   23                   Male       86
# 751   26                 Female      179
# 752   15                 Female      116
# 753   20                   Male        4
# 754   31                   Male      104
# 755   22                 Female      179
# 756   22                   Male        6
# 757   35                   Male       11
# 758   20                   Male      122
# 759   19                   Male       87
# 760   29                   Male       81
# 761   28                   Male      175
# 762   36                   Male       52
# 763   27  Other / Non-Disclosed       48
# 764   25                   Male       70
# 765   15                   Male       13
# 766   22                 Female       84
# 767   20                   Male      122
# 768   21                   Male      158
# 769   24                   Male       73
# 770   22                   Male      141
# 771   24                   Male       25
# 772   15                   Male       31
# 773   21                   Male       44
# 774   24                   Male      123
# 775   22                   Male       98
# 776   14                   Male      104
# 777   20                   Male      117
# 778   20                   Male       75
# 779   23                 Female      107
#
#                                      Item Name  Price               SN  \
# 0                  Bone Crushing Silver Skewer   3.37        Aelalis34
# 1    Stormbringer, Dark Blade of Ending Misery   2.32           Eolo46
# 2                              Primitive Blade   2.46      Assastnya25
# 3                                 Final Critic   1.36     Pheusrical25
# 4                               Stormfury Mace   1.27           Aela59
# 5                                  Sleepwalker   1.73       Tanimnya91
# 6                              Mercenary Sabre   4.57      Undjaskla97
# 7       Interrogator, Blood Blade of the Queen   3.32     Iathenudil29
# 8             Ghost Reaver, Longsword of Magic   2.77     Sondenasta63
# 9         Expiration, Warscythe Of Lost Worlds   4.53       Hilaerin92
# 10             Despair, Favor of Due Diligence   3.81       Chamosia29
# 11                 Alpha, Reach of Ending Hope   1.55          Sally64
# 12                                   Dreamkiss   4.06        Iskossa88
# 13                  Piety, Guardian of Riddles   3.68  Seorithstilis90
# 14                       Bonecarvin Battle Axe   2.46        Sundast29
# 15                 Blood-Forged Skeletal Spine   4.77       Haellysu29
# 16                           Twilight's Carver   1.14       Sundista85
# 17               Lightning, Etcher of the King   1.65        Aenarap34
# 18                                     Celeste   3.71        Iskista88
# 19    Winterthorn, Defender of Shifting Worlds   4.89        Assossa43
# 20                  Glimmer, Ender of the Moon   2.33          Irith83
# 21                                Phantomlight   1.79      Iaralrgue74
# 22                                   Brimstone   2.52         Deural48
# 23                         Dragon's Greatsword   2.36       Chanosia65
# 24                   Conqueror Adamantite Mace   1.96         Qarwen67
# 25                              Stormfury Mace   1.27           Idai61
# 26                                  Persuasion   3.90    Aerithllora36
# 27                         Crying Steel Sickle   2.29      Assastnya25
# 28            The Oculus, Token of Lost Worlds   4.23      Ilariarin45
# 29                         Glinting Glass Edge   2.46        Phaedai25
# ..                                         ...    ...              ...
# 750                          Stormfury Lantern   1.28         Eollym91
# 751            Wolf, Promise of the Moonwalker   1.88     Lisjasksda68
# 752                    Renewed Skeletal Katana   2.37    Yalostiphos68
# 753                         Bloodlord's Fetish   2.28      Thryallym62
# 754                         Gladiator's Glaive   1.36      Sondastan54
# 755            Wolf, Promise of the Moonwalker   1.88      Ailaesuir66
# 756                                Rusty Skull   1.20         Siasri67
# 757                                  Brimstone   2.52         Seosri62
# 758                           Unending Tyranny   1.21      Ryastycal90
# 759                   Deluge, Edge of the West   2.20    Chanirrasta87
# 760                                  Dreamkiss   4.06    Aerithllora36
# 761                 Woeful Adamantite Claymore   1.24      Raeduerin33
# 762                                     Hatred   4.39      Lisosiast26
# 763            Rage, Legacy of the Lone Victor   4.32       Eurisuru25
# 764                                 Hope's End   3.89     Assassasda84
# 765                                   Serenity   1.49    Aerithnucal56
# 766                                 Arcane Gem   2.23      Nitherian58
# 767                           Unending Tyranny   1.21      Hailaphos89
# 768         Darkheart, Butcher of the Champion   3.56     Chamucosda93
# 769                                Ritual Mace   3.74   Frichilsasya78
# 770                                 Persuasion   3.27         Aenasu69
# 771                                  Hero Cane   1.03       Lassista97
# 772                                  Trickster   2.07          Sidap51
# 773                      Bonecarvin Battle Axe   2.46    Chamadarsda63
# 774                          Twilight's Carver   1.14     Lassassast73
# 775                Deadline, Voice Of Subtlety   3.62          Eural50
# 776                         Gladiator's Glaive   1.36       Lirtossa78
# 777          Heartstriker, Legacy of the Light   4.15       Tillyrin30
# 778                    Brutality Ivory Warmace   1.72       Quelaton80
# 779                  Splitter, Foe Of Subtlety   3.61           Alim85
#
#     Age Category
# 0          Adult
# 1          Youth
# 2          Adult
# 3          Youth
# 4          Youth
# 5          Youth
# 6          Youth
# 7          Youth
# 8          Youth
# 9          Adult
# 10         Youth
# 11         Youth
# 12         Youth
# 13         Youth
# 14         Adult
# 15         Youth
# 16         Youth
# 17         Youth
# 18         Youth
# 19         Adult
# 20         Youth
# 21        Infant
# 22        Infant
# 23         Youth
# 24        Infant
# 25         Youth
# 26         Youth
# 27         Adult
# 28        Infant
# 29         Youth
# ..           ...
# 750        Youth
# 751        Youth
# 752       Infant
# 753        Youth
# 754        Adult
# 755        Youth
# 756        Youth
# 757        Adult
# 758        Youth
# 759        Youth
# 760        Youth
# 761        Youth
# 762        Adult
# 763        Youth
# 764        Youth
# 765       Infant
# 766        Youth
# 767        Youth
# 768        Youth
# 769        Youth
# 770        Youth
# 771        Youth
# 772       Infant
# 773        Youth
# 774        Youth
# 775        Youth
# 776       Infant
# 777        Youth
# 778        Youth
# 779        Youth
#
# [780 rows x 7 columns]

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Count purchases by age group
purchase_count_age = df["Item ID"].count()

# Create new data frame with the added "Age Group" and group it
age_grouped = df.groupby("Age Category").count()["Price"]

# # Format the data frame with no index name in the corner
# age_demographics.index.name = None

# # Format with currency style
# age_demographics.style.format({"Average Purchase Price":"${:,.2f}",
#                                "Total Purchase Value":"${:,.2f}",
#                                "Average Purchase Total per Person":"${:,.2f}"})

# %%
age_grouped
# Out:
# Age Category
# Infant     110
# Youth      565
# Adult      105
# Senior       0
# Senior1      0
# Senior2      0
# Name: Price, dtype: int64

# %%
# # Obtain average purchase price by age group 
avg_purchase_price_age = df.groupby("Age Category")["Price"].mean()

# %%
avg_purchase_price_age
# Out:
# Age Category
# Infant     2.916091
# Youth      2.922425
# Adult      2.994190
# Senior          NaN
# Senior1         NaN
# Senior2         NaN
# Name: Price, dtype: float64

# %%
# # Calculate total purchase value by age group 
total_purchase_value = df.groupby("Age Category")["Price"].sum()

# %%
type(total_purchase_value)
# Out:
# pandas.core.series.Series

# %%
# # Calculate the average purchase per person in the age group 
avg_purchase_per_person_age = total_purchase_value/age_grouped

# %%
avg_purchase_per_person_age
# Out:
# Age Category
# Infant     2.916091
# Youth      2.922425
# Adult      2.994190
# Senior          NaN
# Senior1         NaN
# Senior2         NaN
# Name: Price, dtype: float64

# %%
type(avg_purchase_per_person_age)
# Out:
# pandas.core.series.Series

# %%
# # Create data frame with obtained values
age_demographics = pd.DataFrame({"Age Category": age_grouped,
                                "Average Purchase Price": avg_purchase_price_age,
                                "Total Purchase Value":total_purchase_value,
                                "avg_purchase_per_person_age":avg_purchase_per_person_age})

# %%
age_demographics
# Out:
#               Age Category  Average Purchase Price  Total Purchase Value  \
# Age Category
# Infant                 110                2.916091                320.77
# Youth                  565                2.922425               1651.17
# Adult                  105                2.994190                314.39
# Senior                   0                     NaN                  0.00
# Senior1                  0                     NaN                  0.00
# Senior2                  0                     NaN                  0.00
#
#               avg_purchase_per_person_age
# Age Category
# Infant                           2.916091
# Youth                            2.922425
# Adult                            2.994190
# Senior                                NaN
# Senior1                               NaN
# Senior2                               NaN

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Create new data frame with items related information 
items = purchase_data[["Item ID", "Item Name", "Price"]]

# Group the item data by item id and item name 
item_stats = items.groupby(["Item ID","Item Name"])

# Count the number of times an item has been purchased 
purchase_count_item = item_stats["Price"].count()

# Calcualte the purchase value per item 
purchase_value = (item_stats["Price"].sum()) 

# Find individual item price
item_price = purchase_value/purchase_count_item

# Create data frame with obtained values
most_popular_items = pd.DataFrame({"Purchase Count": purchase_count_item, 
                                   "Price": item_price,
                                   "Total Purchase Value":purchase_value})

# Sort in descending order to obtain top spender names and provide top 5 item names
popular_formatted = most_popular_items.sort_values(["Purchase Count"], ascending=False).head()

# Format with currency style
popular_formatted.style.format({"Price":"${:,.2f}",
                                "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72level0_row0" class="row_heading level0 row0" >39</th>
#                         <th id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72level1_row0" class="row_heading level1 row0" >Betrayal, Whisper of Grieving Widows</th>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row0_col0" class="data row0 col0" >11</td>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row0_col1" class="data row0 col1" >$2.35</td>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row0_col2" class="data row0 col2" >$25.85</td>
#             </tr>
#             <tr>
#                         <th id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72level0_row1" class="row_heading level0 row1" >84</th>
#                         <th id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72level1_row1" class="row_heading level1 row1" >Arcane Gem</th>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row1_col0" class="data row1 col0" >11</td>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row1_col1" class="data row1 col1" >$2.23</td>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row1_col2" class="data row1 col2" >$24.53</td>
#             </tr>
#             <tr>
#                         <th id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72level0_row2" class="row_heading level0 row2" >31</th>
#                         <th id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72level1_row2" class="row_heading level1 row2" >Trickster</th>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row2_col0" class="data row2 col0" >9</td>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row2_col1" class="data row2 col1" >$2.07</td>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row2_col2" class="data row2 col2" >$18.63</td>
#             </tr>
#             <tr>
#                         <th id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72level0_row3" class="row_heading level0 row3" >175</th>
#                         <th id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72level1_row3" class="row_heading level1 row3" >Woeful Adamantite Claymore</th>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row3_col0" class="data row3 col0" >9</td>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row3_col1" class="data row3 col1" >$1.24</td>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row3_col2" class="data row3 col2" >$11.16</td>
#             </tr>
#             <tr>
#                         <th id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72level0_row4" class="row_heading level0 row4" >13</th>
#                         <th id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72level1_row4" class="row_heading level1 row4" >Serenity</th>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row4_col0" class="data row4 col0" >9</td>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row4_col1" class="data row4 col1" >$1.49</td>
#                         <td id="T_21a61ca4_a8fb_11e9_8a09_28c2dd9f6d72row4_col2" class="data row4 col2" >$13.41</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
# Take the most_popular items data frame and change the sorting to find highest total purchase value
popular_formatted = most_popular_items.sort_values(["Total Purchase Value"],
                                                   ascending=False).head()
# Format with currency style
popular_formatted.style.format({"Price":"${:,.2f}",
                                "Total Purchase Value":"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72level0_row0" class="row_heading level0 row0" >34</th>
#                         <th id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72level1_row0" class="row_heading level1 row0" >Retribution Axe</th>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row0_col0" class="data row0 col0" >9</td>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row0_col1" class="data row0 col1" >$4.14</td>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row0_col2" class="data row0 col2" >$37.26</td>
#             </tr>
#             <tr>
#                         <th id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72level0_row1" class="row_heading level0 row1" >115</th>
#                         <th id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72level1_row1" class="row_heading level1 row1" >Spectral Diamond Doomblade</th>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row1_col0" class="data row1 col0" >7</td>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row1_col1" class="data row1 col1" >$4.25</td>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row1_col2" class="data row1 col2" >$29.75</td>
#             </tr>
#             <tr>
#                         <th id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72level0_row2" class="row_heading level0 row2" >32</th>
#                         <th id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72level1_row2" class="row_heading level1 row2" >Orenmir</th>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row2_col0" class="data row2 col0" >6</td>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row2_col1" class="data row2 col1" >$4.95</td>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row2_col2" class="data row2 col2" >$29.70</td>
#             </tr>
#             <tr>
#                         <th id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72level0_row3" class="row_heading level0 row3" >103</th>
#                         <th id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72level1_row3" class="row_heading level1 row3" >Singed Scalpel</th>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row3_col0" class="data row3 col0" >6</td>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row3_col1" class="data row3 col1" >$4.87</td>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row3_col2" class="data row3 col2" >$29.22</td>
#             </tr>
#             <tr>
#                         <th id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72level0_row4" class="row_heading level0 row4" >107</th>
#                         <th id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72level1_row4" class="row_heading level1 row4" >Splitter, Foe Of Subtlety</th>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row4_col0" class="data row4 col0" >8</td>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row4_col1" class="data row4 col1" >$3.61</td>
#                         <td id="T_21b8b79e_a8fb_11e9_8327_28c2dd9f6d72row4_col2" class="data row4 col2" >$28.88</td>
#             </tr>
#     </tbody></table>
